# %% [markdown]
# # *Data Science Unit 4 Sprint 2 Assignment 1*
#
# Use TensorFlow Keras and a sample of the [Quickdraw dataset](https://github.com/googlecreativelab/quickdraw-dataset) to build a sketch classification model. The dataset has been sampled to only 10 classes and 10000 observations per class.
#
# ### Objective
#
# - Build a baseline classification model then, run a few experiments with different optimizers and learning rates.
# - Don't forget to [**switch to GPU if you're running your notebook on Colab!**](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# ## Load Your Data

# %%
# imports in first cell 
import seaborn as sns
import pandas as pd
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# use Sequential to build out your model
from tensorflow.keras.models import Sequential

# Dense layer is used for Fully Connected Forward Feeding networks
from tensorflow.keras.layers import Dense

# %% [markdown]
# Note that the 28x28 quickdraw images have already been "flattened" into 784: dimensional vectors

# %%
# load the quickdraw data set
import sys
if 'google.colab' in sys.modules:
    # !git clone https://github.com/LambdaSchool/DS-Unit-4-Sprint-2-Neural-Networks
    datapath = "/content/DS-Unit-4-Sprint-2-Neural-Networks/quickdraw10.npz"
else:
    datapath = "../quickdraw10.npz"

data = np.load(datapath)

X = data['arr_0']
y = data['arr_1']

print(X.shape)
print(y.shape)
# Out:
# (100000, 784)
# (100000,)

# %% [markdown]
# These are the names of the 10 image classes

# %%
class_names = ['apple',
             'anvil',
             'airplane',
             'banana',
             'The Eiffel Tower',
             'The Mona Lisa',
             'The Great Wall of China',
             'alarm clock',
             'ant',
             'asparagus']

# %% [markdown]
# We can explore the data a bit by reshaping the vectors back to images and displaying them with their labels. <br>
# Turns out the data has 10 blocks of 10,000 images of each of the above labels, in order. <br>
# So the code below displays the first image of each class.

# %%
# these are your 10 unique images
plt.figure(figsize=(10,5))
start = 0

for num, name in enumerate(class_names):
    plt.subplot(2,5, num+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X[start].reshape(28,28),cmap=plt.cm.binary)
    plt.xlabel(name)
    start += 10000
plt.show()

# %% [markdown]
# Say hello to the Quickdraw dataset!
#
# You'll be using this dataset a lot this week as an alternative to the MNIST digits data set, which we'll use in the guided projects. The nice thing about this dataset is that it's simple, which allows us to focus on our model, its various components, and gradually come to a better understanding of how to build neural networks without worrying about cleaning and prepping our image data much.

# %%
# always a good idea to shuffle your dataset!
X, y = shuffle(X, y)

# %% [markdown]
# -----
#
# ## Build Your Baseline Model
#
# Make sure that you
#
# - **Determine** the dimensionality of your input data by investigating **X**
# - **Normalize** your input data to values between 0 and 1
# - **Determine** the number of neurons in your output layer by investigating **Y**
# - **Select** `sparse_categorical_crossentropy` as your loss function.
# - **Select** `sgd` as your optimizer.
# - **Add** 3 hidden layers to your model with the following number of nodes
#     - h1 has 500 nodes
#     - h2 has 250 nodes
#     - h3 has 100 nodes
#
# - **Set** epochs to 20
# - **Use** the `validation_split` keyword in `model.fit()` to automatically create a training / validation dataset from within the model. Specify a percentage, such as `validation_split = 0.2`
#
# Not sure what the various parameters are for or what values to assign to them?
#
# - Reference the guided project notebook for Sprint 2 Module 1
# - Reference the [**Keras documentation**](https://keras.io/api/)
# - Google other examples
# - Discuss your results with classmates

# %%
# get dim of image row vectors and save to input_dim

# get number of unique labels and save to n_output_labels

# normalize image data to values between 0 and 1 (by dividing by max pixel value)

# dataset is pre-flattened
input_num = len(X[0])
# unique output labels of the 10 image classes
n_output_labels = len(np.unique(y))
# greyscale, no-alpha images = 255 bit depth
pixel_bits = 255
X_scaled = X.astype('float') / pixel_bits

# %%
# a check on your data prep 
assert  X_scaled.max(), "Max pixel value should be 1.0, make sure you normalize your data"

# %%
# instantiate a sequential object and call it model, then add the layers to your model

# add a compile layer but don't fit your model yet 

model = Sequential()
# initial layer
# model.add(Dense(32, activation='relu', input_dim=input_num))
# hidden layers
model.add(Dense(500, activation='relu', input_dim=input_num))
model.add(Dense(250, activation='relu'))
model.add(Dense(100, activation='relu'))
# output layer
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.get_config()["layers"][0]
# Out:
# {'class_name': 'InputLayer',
#  'config': {'batch_input_shape': (None, 784),
#   'dtype': 'float32',
#   'sparse': False,
#   'ragged': False,
#   'name': 'dense_47_input'}}

# %%
# a check on your model architecture 
n_layers = len(model.get_config()["layers"])
assert n_layers == 5, "You should have 5 layers: input, h1, h2, h3, and output"

# %%
# check out your model summary 
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_47 (Dense)            (None, 500)               392500
#
#  dense_48 (Dense)            (None, 250)               125250
#
#  dense_49 (Dense)            (None, 100)               25100
#
#  dense_50 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 543,860
# Trainable params: 543,860
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 20

# fit your model and save training results to history 
history = model.fit(X_scaled, y, 
                    epochs=epochs, 
                    # a held-out validation set will be generated within the model
                    validation_split=0.2
                   )
# Out:
# Epoch 1/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.9859 - accuracy: 0.7084 - val_loss: 0.7110 - val_accuracy: 0.7914
# Epoch 2/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.6595 - accuracy: 0.8072 - val_loss: 0.6054 - val_accuracy: 0.8184
# Epoch 3/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.5644 - accuracy: 0.8324 - val_loss: 0.5484 - val_accuracy: 0.8353
# Epoch 4/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.5039 - accuracy: 0.8508 - val_loss: 0.5081 - val_accuracy: 0.8473
# Epoch 5/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.4565 - accuracy: 0.8651 - val_loss: 0.4846 - val_accuracy: 0.8534
# Epoch 6/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.4183 - accuracy: 0.8769 - val_loss: 0.4489 - val_accuracy: 0.8656
# Epoch 7/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.3848 - accuracy: 0.8874 - val_loss: 0.4554 - val_accuracy: 0.8659
# Epoch 8/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.3573 - accuracy: 0.8949 - val_loss: 0.4305 - val_accuracy: 0.8732
# Epoch 9/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.3307 - accuracy: 0.9036 - val_loss: 0.4331 - val_accuracy: 0.8722
# Epoch 10/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.3064 - accuracy: 0.9104 - val_loss: 0.4339 - val_accuracy: 0.8736
# Epoch 11/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.2837 - accuracy: 0.9172 - val_loss: 0.4193 - val_accuracy: 0.8797
# Epoch 12/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.2628 - accuracy: 0.9240 - val_loss: 0.4271 - val_accuracy: 0.8770
# Epoch 13/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.2423 - accuracy: 0.9301 - val_loss: 0.4309 - val_accuracy: 0.8788
# Epoch 14/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.2231 - accuracy: 0.9352 - val_loss: 0.4408 - val_accuracy: 0.8753
# Epoch 15/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.2046 - accuracy: 0.9415 - val_loss: 0.4461 - val_accuracy: 0.8770
# Epoch 16/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.1874 - accuracy: 0.9462 - val_loss: 0.4450 - val_accuracy: 0.8786
# Epoch 17/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.1707 - accuracy: 0.9523 - val_loss: 0.4569 - val_accuracy: 0.8776
# Epoch 18/20
# 2500/2500 [==============================] - 15s 6ms/step - loss: 0.1549 - accuracy: 0.9560 - val_loss: 0.4721 - val_accuracy: 0.8756
# Epoch 19/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.1397 - accuracy: 0.9617 - val_loss: 0.5172 - val_accuracy: 0.8694
# Epoch 20/20
# 2500/2500 [==============================] - 14s 6ms/step - loss: 0.1262 - accuracy: 0.9648 - val_loss: 0.4910 - val_accuracy: 0.8775

# %% [markdown]
# ----
# ### Visualize the Results
#
# - Move results in `history` to a dataframe.
# - Use [**Seaborn**](https://seaborn.pydata.org/generated/seaborn.lineplot.html) to create line plots for both loss and accuracy by epoch.
# - Analyze the results and write a couple of observations.
#
# At what point should we have stopped training the model and why?

# %%
df = pd.DataFrame(history.history)
df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.985918  0.708375  0.710984       0.79135
# 1  0.659469  0.807150  0.605364       0.81840
# 2  0.564442  0.832412  0.548420       0.83530
# 3  0.503918  0.850788  0.508125       0.84730
# 4  0.456477  0.865125  0.484594       0.85340

# %%
# a check on our model training
assert df.shape[0] == 20, "df should have the training results from 20 epochs"

# %%
# use seaborn to plot loss and accuracy metrics

epochs = range(0, len(df['loss']))
sns.lineplot(x=epochs, y=df['loss'], label="train")
sns.lineplot(x=epochs, y=df['val_loss'], label="test")
plt.title('Loss')
plt.grid()

# %%
epochs = range(0, len(df['accuracy']))
sns.lineplot(x=epochs, y=df['accuracy'], label="train")
sns.lineplot(x=epochs, y=df['val_accuracy'], label="test")
plt.title('Accuracy')
plt.grid()

# %% [markdown]
# ### Observations
#
# Based on the plot of the training and validation loss, answer the following questions.

# %% [markdown]
# **Was our model able to learn throughout the 20 epochs? Why or why not?**

# %% [markdown]
# The accuracy continued to trend upward for every epoch (and conversely the loss decreased) indicating the model was continuing to refine its weights for all 20 epochs

# %% [markdown]
# **Is our model overfitting? Why or why not?**

# %% [markdown]
# The model ends up overfiting itself after about 10 epochs, as the training accuracy continues to increase but the validation accuracy metrics stagnate or decrease

# %% [markdown]
# **Could the model score benefit from additional epochs? Why or why not?**

# %% [markdown]
# No, the model stopped improving its actual predictive abilities after epochs 10-11 so further training will not meaningfully improve this model

# %% [markdown]
# -----
# ## Change Optimizers
#
# Let's compare model performance between different optimizers.
# - Build a new model, identical to the last one but using `adam` for the optimizer.
# - Train (fit) the model
# - Save the modeling results to adam_history, so we don't erase the results from the previous model run
# - Visualize the training results just as we did for the last model.

# %%
# train the same model as above but use the sgd optimizer if you used adam previously (or use adam if you used sgd previously)

model = Sequential()
# hidden layers
model.add(Dense(500, activation='relu', input_dim=input_num))
model.add(Dense(250, activation='relu'))
model.add(Dense(100, activation='relu'))
# output layer
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# a check that we're using the correct optimizer in this model
opt_name = model.optimizer.get_config()["name"]
assert opt_name == "Adam", "you need to use adam for the optimizer in this model."

# %%
epochs = 20
adam_history = model.fit(X_scaled, y, 
                    epochs=epochs,
                    validation_split=0.2
                   )
# Out:
# Epoch 1/20
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.5939 - accuracy: 0.8181 - val_loss: 0.4715 - val_accuracy: 0.8563
# Epoch 2/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.4185 - accuracy: 0.8723 - val_loss: 0.4302 - val_accuracy: 0.8689
# Epoch 3/20
# 2500/2500 [==============================] - 16s 7ms/step - loss: 0.3453 - accuracy: 0.8940 - val_loss: 0.4058 - val_accuracy: 0.8765
# Epoch 4/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.2947 - accuracy: 0.9081 - val_loss: 0.4259 - val_accuracy: 0.8734
# Epoch 5/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.2511 - accuracy: 0.9220 - val_loss: 0.4482 - val_accuracy: 0.8766
# Epoch 6/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.2135 - accuracy: 0.9329 - val_loss: 0.4695 - val_accuracy: 0.8771
# Epoch 7/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.1853 - accuracy: 0.9412 - val_loss: 0.4906 - val_accuracy: 0.8806
# Epoch 8/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.1599 - accuracy: 0.9482 - val_loss: 0.5457 - val_accuracy: 0.8745
# Epoch 9/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.1442 - accuracy: 0.9540 - val_loss: 0.5626 - val_accuracy: 0.8791
# Epoch 10/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.1272 - accuracy: 0.9588 - val_loss: 0.5670 - val_accuracy: 0.8789
# Epoch 11/20
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.1139 - accuracy: 0.9632 - val_loss: 0.6419 - val_accuracy: 0.8815
# Epoch 12/20
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.1049 - accuracy: 0.9656 - val_loss: 0.6791 - val_accuracy: 0.8778
# Epoch 13/20
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0951 - accuracy: 0.9692 - val_loss: 0.7341 - val_accuracy: 0.8749
# Epoch 14/20
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0909 - accuracy: 0.9704 - val_loss: 0.7433 - val_accuracy: 0.8716
# Epoch 15/20
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0830 - accuracy: 0.9733 - val_loss: 0.7418 - val_accuracy: 0.8802
# Epoch 16/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.0762 - accuracy: 0.9758 - val_loss: 0.7638 - val_accuracy: 0.8778
# Epoch 17/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.0727 - accuracy: 0.9768 - val_loss: 0.8577 - val_accuracy: 0.8794
# Epoch 18/20
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0701 - accuracy: 0.9777 - val_loss: 0.8469 - val_accuracy: 0.8746
# Epoch 19/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.0689 - accuracy: 0.9784 - val_loss: 0.8333 - val_accuracy: 0.8792
# Epoch 20/20
# 2500/2500 [==============================] - 17s 7ms/step - loss: 0.0627 - accuracy: 0.9807 - val_loss: 0.8705 - val_accuracy: 0.8760

# %%
df_adam = pd.DataFrame(adam_history.history)

epochs = range(0, len(df_adam['loss']))
sns.lineplot(x=epochs, y=df_adam['loss'], label="train")
sns.lineplot(x=epochs, y=df_adam['val_loss'], label="test")
plt.title('Loss')
plt.grid()

# %%
epochs = range(0, len(df['accuracy']))
sns.lineplot(x=epochs, y=df_adam['accuracy'], label="train")
sns.lineplot(x=epochs, y=df_adam['val_accuracy'], label="test")
plt.title('Accuracy')
plt.grid()

# %% [markdown]
# ### Observations
#
# This plot should look very different from the previous plot. Based on the plot of the training and validation loss, answer the following questions.

# %% [markdown]
# **Is our model overfitting? Why or why not?**

# %% [markdown]
# No, based on the validation loss curve, this model overfits itself much earlier (at about 2-3 epochs) and continues to much more sharply overfit

# %% [markdown]
# **Could our model's performance improve by training on more than 20 epochs? Why or why not?**

# %% [markdown]
# Very unlikely, given the test loss continues to increase and the test accuracy stagnates as early as after 6 epochs

# %% [markdown]
# **Assuming that you want to stick to this model architecture, what can you do to avoid overfitting?**

# %% [markdown]
# Models with this optimization type should use much lower maximum epochs

# %% [markdown]
# ------
# # Conclusion
#
# You have observed by comparing the two models that are identical except for the optimizer, that the choice of the optimizer can considerably influence the performance of a neural network.
#
# You might not know
#
# - why changing the optimizer from Stochastic Gradient Descent over to Adam made a difference.
# - how Gradient Descent works
# - or that Adam is known as Adaptive Gradient Descent (i.e., is it a different version of ordinary Gradient Descent).
#
# But that's ok - tomorrow's lesson will be a deep dive into Gradient Descent. You'll learn the theory of Gradient Descent, we'll code up Gradient Descent from scratch, and we'll talk about how Adam is different from ordinary Gradient Descent.

# %% [markdown]
# -----
# # Preparation for Tomorrow
#
# In preparation for tomorrow, you might need to watch a few videos. I say it might because you may or may not already be comfortable with multi-variate calculus.
#
# ### Theory of Calculus
# The theory of Gradient Descent rests on [**the derivative from Calculus**](https://www.youtube.com/watch?v=WUvTyaaNkzM). If you've never taken a Calculus course before, or are a bit rusty, definitely watch this video in preparation for tomorrow's lesson. The takeaway here is to understand the derivative conceptually; you won't be asked to calculate any derivatives by hand.
#
# ### The Gradient - a Multi-Dimensional Derivative
# Once you've watched the previous video, you will be ready to understand how to conceptualize a derivative in an N-dimensional space (where N is any number ranging from 2, 3, 4, ..., all the way to a very large number of dimensions N ). [**This video visually explains the multi-dimensional derivative called the Gradient visually**](https://www.youtube.com/watch?v=GkB4vW16QHI) - and that's the takeaway. The point of this video is to help you understand the Gradient visually using 3D surfaces. You should also know that the Gradient is made up of partial derivatives, more on this tomorrow.
#
# ### Contour Maps
# It is very common to visual 3D surfaces as 2D contour maps - and we'll be making a lot of use of contour maps to understand Gradient Descent. Watch this video to [**understand the relationship between 3D surfaces and 2D contour maps.**](https://www.youtube.com/watch?v=acdX4YamDtU)
#
# ### The Calculus of Backpropagation
#
# Unlike standard Sklearn ML models, neural networks use Gradient Descent and something called Backpropagation to learn from the data. [**In order to understand how backpropagation works, you need to understand the Chain Rule in Calculus**](https://www.youtube.com/watch?v=acdX4YamDtU). The takeaway here is to understand how a partial derivative can be decomposed into a product of multiple derivatives.

# %% [markdown]
# ------
# # Stretch Goals
#
# ### This Section is Optional!
#
# Only after you've completed the above work and watched the recommended videos are you then encouraged to experiment with building a few more models and analyze their results.
#
# Here are some suggestions to help you get started.
#
# - Train the same model using the Sigmoid and Relu activation functions and note the difference in their learning outcomes. [**Keras docs on activation functions**](https://keras.io/api/layers/activations/). We'll cover the Relu activation function in Sprint 2 Module 3.
# - Train the same model using normalized and non-normalized data and note the difference in their learning outcomes.
#
#
# The objective here is to get more practice with the Keras API (i.e., building models) and run a couple of experiments to help set you up for future lessons. In order words, we'll be discussing different activation functions and the effect of normalized data on model training.
